# %%
#imports
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt

#import settings
pd.set_option('display.max_columns', None)

# get data
dataframe_all = pd.read_csv('df_training_scholarjet_sm100.csv')
num_rows = dataframe_all.shape[0]
print(num_rows)

counter_nan = dataframe_all.isnull().sum()
print(type(counter_nan))

counter_without_nan = counter_nan[counter_nan==0]

# x = a
# Out:
# 99
# <class 'pandas.core.series.Series'>

# %%
# MAIN FILE FOR ENTIRE PROJECT, ALL OTHERS ARE ITERATIOSN

#imports
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt


import pickle

#import settings
pd.set_option('display.max_columns', None)

# get data
allData = pd.read_csv('df_training_scholarjet_sm100.csv')
# allData = pd.read_csv('df_training_scholarjet.csv')

num_rows = allData.shape[0]
print(num_rows)








# #grab the two rows for comparison
# allData = allData[['convert_30', 'revenue_30', 'roll_up',]]
# # print(allData.head(10))

# cnt = 0
# cntBuys = 0 

# # print(len(allData.values[:]))




# for row in range(100):
#     print(allData.values[row,1])










# print(allData.head(20))
# print(allData.loc[7,])

# for row, col in allData.iterrows():
#     print(row)
#     print(col)
#     print()

# print(len(allData.values[:]))
# for row in allData.iterrows():
#     print(row)
#     print()
    
    
    
# print(allData.iterrows())
# for index, row in allData.head().iterrows():
#     columnlabels = allData.loc[]
#     count =+1
#     print(next(allData.iterrows())[count])
    # target row for printing, iter row what does it return
    # for each row in allData, now I need to target that row
    # target row =
#     print(allData.head().iterrows())
#     print(type(allData.head().iterrows()))
    
# with open('sells.log') as file:
#     pizza_col = (line[3] for line in file)
#     per_hour = (int(x) for x in pizza_col if x != 'N/A')
#     print("Total pizzas sold = ",sum(per_hour))
    
    
# print(count)

# print(allData.type())

# allData.drop("", axis=1)

# print(allData.head(1))

# gather data - roll_up analysis
# only get data from convert30 and rollup 

# sort the data by convert 30

# analyze data 

# create new textfile to hold percentage statistics
# filename = 'featureEnginering.sav'
# pickle.dump(clf, open(filename, 'wb'))

# clf = pickle.load(open(filename, 'rb'))



# print(trainingData.head(1))
# Out:
# 99

# %%
#imports
import pandas as pd
import numpy as np
import pickle
#import settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)


# get data
allData = pd.read_csv('df_training_scholarjet_sm100.csv')
# allData = pd.read_csv('df_training_scholarjet.csv')

#grab the two rows for comparison
allData = allData[['revenue_30', 'roll_up',]]

# print(type(allData.head(10)))
df = (type(allData.head(10)))
print(df.dtypes)
      





# # iterate over rows with iterrows()
# for index, row in allData.head().iterrows():
#      access data using column names
#      print(index, row['convert_30'], row['roll_up'])


# with open('df_training_scholarjet_sm100.csv') as file:
# #     pizza = (line[3] for line in file)
# #     print(pizza)
    

# learning how to manipulate dataframes

import pandas as pd

# make dataframes
df = pd.DataFrame([[2, 1, 3], [2, 4, 1], [10, 20, 30]])

# print its shape
# print(df.shape)

# get by row
print(df.loc[0,0]==2)






# print(df.iterrows().values)

# get by column


# print(df.iterrows())
# for index in df.iterrows():
# #     for dindex in df.iter
#     print(df.loc[:,'B'].values)
# print(df.loc[0,:].values)
# Out:
# -------------------------------------
# KeyErrorTraceback (most recent call last)
# <ipython-input-2-6c69921210be> in <module>()
#      14
#      15 #grab the two rows for comparison
# ---> 16 allData = allData[['revenue_30', 'roll_up',]]
#      17
#      18 # print(type(allData.head(10)))
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# ...

# %%
# learning how to manipulate dataframes

import pandas as pd

# make dataframes
df = pd.DataFrame([[2, 1, 3], [2, 4, 1], [10, 20, 30]])

# print its shape
# print(df.shape)

# get by row
print(df.loc[0,0]==2)






# print(df.iterrows().values)

# get by column


# print(df.iterrows())
# for index in df.iterrows():
# #     for dindex in df.iter
#     print(df.loc[:,'B'].values)
# print(df.loc[0,:].values)
# Out:
# True
