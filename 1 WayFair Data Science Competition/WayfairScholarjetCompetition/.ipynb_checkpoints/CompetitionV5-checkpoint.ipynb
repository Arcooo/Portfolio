# %%
# Python Library Imports 
import pandas as pd  # for Dataframes
import numpy as np  # for arrays

import sklearn  # for machine learning
from sklearn import tree 








# from sklearn.preprocessing import StandardScaler  # for preprocessing 
# from sklearn.model_selection import train_test_split  # for spliting the data
# from sklearn import preprocessing

# import matplotlib.pyplot as plt  # for plotting visuals

# import pickle # for persistance

# %%
# Data Imports
csvfile = "df_training_scholarjet.csv"  # dataset to be used
dataframe_all = pd.read_csv(csvfile, index_col=0)  # read csvs file
df_shape = dataframe_all.shape  # save shape
dataframe_all.index = range(df_shape[0])  # reindex dataframe

print(df_shape)  # see shape of dataframe
# dataframe_all.head()
# Out:
# (28126, 183)

# %%
clf = tree.DecisionTreeClassifier()
clf.fit(train_data, train_target)
# Out:
# [1, 2, 0, 1, 2]

# %%
# https://www.youtube.com/watch?v=84gqSbLcBFE&list=PLOU2XLYxmsIIuiBfYad6rFYQU_jL2ryal&index=4

from sklearn import datasets
iris = datasets.load_iris()

X = iris.data
y= iris.target

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .5)

from sklearn import tree
myclf = tree.DecisionTreeClassifier()

myclf.fit(X_train, y_train)

predictions = myclf.predict(X_test)
print(predictions)

from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, predictions))

# %%
import numpy as np
from sklearn.datasets import load_iris
iris = load_iris()
test_idx = [0,50,100]

print(iris)
train_target = np.delete(iris.target, test_idx)
print(train_target)
train_data = np.delete(iris.data, test_idx, axis=0)
print(train_data)


test_target = iris.target[test_idx]
test_data = iris.data[test_idx]
                         
clf = tree.DecisionTreeClassifier()
clf.fit(train_data, train_target)

print (test_target)
print(clf.predict(test_data))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sklearn\utils\__init__.py in __getattr__(self, key)
#      60         try:
# ---> 61             return self[key]
#      62         except KeyError:
#
# KeyError: 'attributes'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-0a7e38af0d3d> in <module>()
#       4 test_idx = [0,50,100]
#       5
# ----> 6 print(iris.attributes)
#       7 train_target = np.delete(iris.target, test_idx)
#       8 print(train_target)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\__init__.py in __getattr__(self, key)
#      61             return self[key]
#      62         except KeyError:
# ---> 63             raise AttributeError(key)
#      64
#      65     def __setstate__(self, state):
#
# AttributeError: attributes

# %%
from sklearn.externals.six import StringIO
import pydot
from IPython.display import Image

dot_data = StringIO()
tree.export_graphviz(clf, 
                     out_file=dot_data, feature_names=iris.feature_names,
                     class_names = iris.target_names,
                     filled=True, rounded=True, 
                     impurity=False)
(graph, ) = pydot.graph_from_dot_data(dot_data.getvalue())  
# graph.write_pdf("iris.pdf")
Image(graph.create_png())

# %%
#from video 

features = [[140,1], [130,1], [150,0], [170,0]]
labels = [0,0,1,1]

clf = tree.DecisionTreeClassifier()
clf = clf.fit(features, labels)
print(clf.predict([[170,0]]))
# Out:
# [1]

# %%
# from sklearn docs

from sklearn import tree
X = [[0, 0], [1, 1]]
Y = [0, 1]
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, Y)


print(clf.predict([[2., 2.]]))
print(clf.predict_proba([[2., 2.]]))

# mport graphviz 
# dot_data = tree.export_graphviz(clf, out_file=None) 
# graph = graphviz.Source(dot_data) 
# graph.render("iris")
# Out:
# [1]
# [[0. 1.]]

# %%
# !python -m pip install graphviz
# Out:
# Requirement already satisfied: graphviz in c:\users\alecc\anaconda3\lib\site-packages (0.10.1)

# %%
from sklearn.datasets import load_iris
from sklearn import tree
# from sklearn.tree import plot_tree
iris = load_iris()
clf = tree.DecisionTreeClassifier()
clf = clf.fit(iris.data, iris.target)


import graphviz
dot_data = tree.export_graphviz(clf, out_file='iris.dot', 
                      feature_names=iris.feature_names,  
                      class_names=iris.target_names,  
                      filled=True, rounded=True,  
                      special_characters=True)  
# graph = graphviz.Source(dot_data)  
# graph 

# graph.write_pdf("iris.pdf")

print (test_target)
print(clf.predict(test_data))

tree.plot_tree(clf.fit(iris.data, iris.target))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-f63158be079c> in <module>()
#      18 # graph.write_pdf("iris.pdf")
#      19
# ---> 20 print (test_target)
#      21 print(clf.predict(test_data))
#      22
#
# NameError: name 'test_target' is not defined

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree.export import export_text
iris = load_iris()
X = iris['data']
y = iris['target']
decision_tree = DecisionTreeClassifier(random_state=0, max_depth=2)
decision_tree = decision_tree.fit(X, y)
r = export_text(decision_tree, feature_names=iris['feature_names'])
print(r)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-19-0f66595223b7> in <module>()
#       1 from sklearn.datasets import load_iris
#       2 from sklearn.tree import DecisionTreeClassifier
# ----> 3 from sklearn.tree.export import export_text
#       4 iris = load_iris()
#       5 X = iris['data']
#
# ImportError: cannot import name 'export_text' from 'sklearn.tree.export' (C:\Users\alecc\Anaconda3\lib\site-packages\sklearn\tree\export.py)

# %%
# Make a new dataframe for testing
dfIter1 = pd.DataFrame(dataframe_all[['revenue_30', 'roll_up']])
# dfIter1['revenue_30'][1] = 10

# dfIter1
# dataframe_all
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-75c3723c6109> in <module>()
#       1 # Make a new dataframe for testing
# ----> 2 dfIter1 = pd.DataFrame(dataframe_all[['revenue_30', 'roll_up']])
#       3 # dfIter1['revenue_30'][1] = 10
#       4
#       5 # dfIter1
#
# NameError: name 'dataframe_all' is not defined

# %%
# https://www.youtube.com/watch?v=N9fDIAflCMY&list=PLOU2XLYxmsIIuiBfYad6rFYQU_jL2ryal&index=3
import numpy as np
import matplotlib.pyplot as plt

greyhounds = 500
labs = 500

grey_height = 28 +4*np.random.randn(greyhounds)
lab_height = 24 +4*np.random.randn(labs)

plt.hist([grey_height, lab_height], stacked=True, color=['r','b'])
plt.show()

# ideal features are independent simple informative
